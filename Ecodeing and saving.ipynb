# %%
# !wget https://datahub.hku.hk/ndownloader/articles/16674565/versions/1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip  "/content/drive/MyDrive/NLP Project/1.zip" -d "/content/drive/MyDrive/NLP Project/unzipData/"
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/NLP Project/1.zip, /content/drive/MyDrive/NLP Project/1.zip.zip or /content/drive/MyDrive/NLP Project/1.zip.ZIP.

# %%
import os

# %%
os.listdir("./drive/MyDrive/NLP Project")
# Out:
# ['dataset', 'openweiboscope', 'unzipData', 'testNew.csv']

# %%
os.chdir("./drive/MyDrive/NLP Project")

# %%
os.listdir("./dataset")
# Out:
# ['test.xlsx', 'test.csv', 'week2.csv']

# %%
"week1.zip".strip(".zip")
# Out:
# 'week1'

# %%
import pandas as pd

# %%
import codecs
datafolder=os.listdir("./unzipData/")

# %%
import os, zipfile

# dir_name = 'C:\\SomeDirectory'
extension = ".zip"

# os.chdir(dir_name) # c?hange directory from working dir to dir with files?

for item in datafolder: # loop through items in dir
    if item.endswith(extension): # check for ".zip" extension
        zip_ref = zipfile.ZipFile("./unzipData/"+item) # create zipfile object
        zip_ref.extractall("./FinalDataset") # extract file to dir
        zip_ref.close() # close file

# %%
with codecs.open(data, 'r', encoding='utf-8',errors='ignore') as fdata:
  csvData=fdata.read()
with open(dataSave+"p_"+csv, 'w', encoding='utf8') as f:
  f.write(csvData)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1ad567b29da0> in <module>()
# ----> 1 with codecs.open(data, 'r', encoding='utf-8',errors='ignore') as fdata:
#       2   csvData=fdata.read()
#       3 with open(dataSave+"p_"+csv, 'w', encoding='utf8') as f:
#       4   f.write(csvData)
#
# NameError: name 'data' is not defined

# %%
for csv in os.listdir("./FinalDataset/"):
  with codecs.open("./FinalDataset/"+csv, 'r', encoding='utf-8',errors='ignore') as fdata:
    csvData=fdata.read()
  with open("./encodedDataset/"+"p_"+csv, 'w', encoding='utf8') as f:
    f.write(csvData)
