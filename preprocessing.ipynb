# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
os.listdir("./drive/MyDrive/encodedDataset")
# Out:
# ['p_userdata.csv',
#  'p_week11.csv',
#  'p_week12.csv',
#  'p_week13.csv',
#  'p_week14.csv',
#  'p_week15.csv',
#  'p_week16.csv',
#  'p_week17.csv',
#  'p_week18.csv',
#  'p_week19.csv',
#  'p_week20.csv',
#  'p_week21.csv',
#  'p_week22.csv',
#  'p_week23.csv',
#  'p_week24.csv',
#  'p_week25.csv',
#  'p_week26.csv',
#  'p_week27.csv',
#  'p_week28.csv',
#  'p_week29.csv',
#  'p_week30.csv',
#  'p_week31.csv',
#  'p_week32.csv',
#  'p_week33.csv',
#  'p_week34.csv',
#  'p_week35.csv',
#  'p_week36.csv',
#  'p_week37.csv',
#  'p_week38.csv',
#  'p_week39.csv',
#  'p_week40.csv',
#  'p_week41.csv',
#  'p_week42.csv',
#  'p_week43.csv',
#  'p_week44.csv',
#  'p_week45.csv',
#  'p_week46.csv',
#  'p_week47.csv',
#  'p_week48.csv',
#  'p_week49.csv',
#  'p_week50.csv',
#  'p_week51.csv',
#  'p_week52.csv',
#  'p_week1.csv',
#  'p_week6.csv',
#  'p_week10.csv',
#  'p_week4.csv',
#  'p_week3.csv',
#  'p_week7.csv',
#  'p_week2.csv',
#  'p_week9.csv',
#  'p_week8.csv',
#  'p_week5.csv']

# %%
import pandas as pd

# %%
df1 = pd.read_csv('./drive/MyDrive/encodedDataset/p_week1.csv',low_memory=False)
df2 = pd.read_csv('./drive/MyDrive/encodedDataset/p_week2.csv',low_memory=False)
df3 = pd.read_csv('./drive/MyDrive/encodedDataset/p_week3.csv',low_memory=False)
df4 = pd.read_csv('./drive/MyDrive/encodedDataset/p_week4.csv',low_memory=False)
df = pd.concat([df1, df2, df3, df4], axis=0)
df.head()
# Out:
#           mid retweeted_status_mid        uid retweeted_uid source  image  \
# 0  mCClUNCqwe           mU5j0dIAkQ  uK3RXUJ0V           NaN   新浪微博      0
# 1  mRsOcOLTlc           mJGNX5nAmo  uK3RXUJ0V           NaN   新浪微博      0
# 2  mH44qG6iUm           mH44qL9LlF  uK3RXUJ0V           NaN   新浪微博      0
# 3  mZmwFtOdVX           mcyE5GR7GJ  uK3RXUJ0V           NaN   新浪微博      0
# 4  mQkLJSl8bf           muy8VxftBB  uK3RXUJ0V           NaN   新浪微博      0
#
#                                            text  geo           created_at  \
# 0                                          转发微博  NaN  2012-01-03 02:02:27
# 1  !!!!!!!!!@uK3RXUYW3： //@u0AGMTTVD：  ！！！！！！！！  NaN  2012-01-03 01:17:39
# 2                                      求一切順利!!!  NaN  2012-01-03 01:15:36
# 3             想要><@uK3RXUYW3： //@ukn：  全都想要啊QAQ  NaN  2012-01-03 01:12:55
# 4                  //@ukn：  //@uMLLV3ZCO：  转发微博  NaN  2012-01-03 01:10:42
#
#   deleted_last_seen permission_denied
# ...

# %%
# !pip install demoji
# Out:
# ...
#      |████████████████████████████████| 42 kB 804 kB/s
# ...

# %%
import string
import re
import demoji
def preprocess(text):
  text = str(text)
  # remove url from text
  text = re.sub(r'http\S+', '', text)
  # remove the punctuations and emojis from the text
  # text = emoji.replace_emoji(text, '')
  text = demoji.replace(text,"")
  text = "".join([c for c in text if c not in string.punctuation])
  return text

# %%
# preprocessing the text column and writing it to new file
df['text'] = df['text'].apply(preprocess)
df.to_csv('./drive/MyDrive/NLP Project/preprocessed_Data.csv', index=False)
