# %%
import pandas as pd
import os

# %%
df= pd.read_csv("./dataset/week2.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df= pd.read_csv("./dataset/week2.csv")
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1250, in TextFileReader.read(self, nrows)
#    1248 nrows = validate_integer("nrows", nrows)
#    1249 try:
# -> 1250     index, columns, col_dict = self._engine.read(nrows)
#    1251 except Exception:
#    1252     self.close()
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/Documents/nlp/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbc in position 216770: invalid start byte

# %%
df= pd.read_csv("./dataset/week1.csv",encoding='latin1')
# Out:
# /tmp/ipykernel_23204/200840196.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("./dataset/week1.csv",encoding='latin1')

# %%
df.head()
# Out:
#           mid retweeted_status_mid        uid retweeted_uid        source  \
# 0  mCClUNCqwe           mU5j0dIAkQ  uK3RXUJ0V           NaN  æ°æµªå¾®å
# 1  mRsOcOLTlc           mJGNX5nAmo  uK3RXUJ0V           NaN  æ°æµªå¾®å
# 2  mH44qG6iUm           mH44qL9LlF  uK3RXUJ0V           NaN  æ°æµªå¾®å
# 3  mZmwFtOdVX           mcyE5GR7GJ  uK3RXUJ0V           NaN  æ°æµªå¾®å
# 4  mQkLJSl8bf           muy8VxftBB  uK3RXUJ0V           NaN  æ°æµªå¾®å
#
#    image                                               text  geo  \
# 0      0                                       è½¬åå¾®å  NaN
# 1      0  !!!!!!!!!@uK3RXUYW3ï¼ //@u0AGMTTVDï¼  ï¼ï¼...  NaN
# 2      0                                 æ±ä¸åé å©!!!  NaN
# 3      0  æ³è¦><@uK3RXUYW3ï¼ //@uknï¼  å
# ¨é½æ³è¦å...  NaN
# 4      0           //@uknï¼  //@uMLLV3ZCOï¼  è½¬åå¾®å  NaN
#
#             created_at deleted_last_seen permission_denied
# 0  2012-01-03 02:02:27               NaN               NaN
# 1  2012-01-03 01:17:39               NaN               NaN
# 2  2012-01-03 01:15:36               NaN               NaN
# 3  2012-01-03 01:12:55               NaN               NaN
# 4  2012-01-03 01:10:42               NaN               NaN

# %%
import pandas as pd

codecs = ['ascii','big5','big5hkscs','cp037','cp273','cp424','cp437','cp500','cp720','cp737','cp775','cp850','cp852','cp855',
          'cp856','cp857','cp858','cp860','cp861','cp862','cp863','cp864','cp865','cp866','cp869','cp874','cp875','cp932','cp949',
          'cp950','cp1006','cp1026','cp1125','cp1140','cp1250','cp1251','cp1252','cp1253','cp1254','cp1255','cp1256','cp1257','cp1258',
          'euc_jp','euc_jis_2004','euc_jisx0213','euc_kr','gb2312','gbk','gb18030','hz','iso2022_jp','iso2022_jp_1','iso2022_jp_2',
          'iso2022_jp_2004','iso2022_jp_3','iso2022_jp_ext','iso2022_kr','latin_1','iso8859_2','iso8859_3','iso8859_4','iso8859_5','iso8859_6',
          'iso8859_7','iso8859_8','iso8859_9','iso8859_10','iso8859_11','iso8859_13','iso8859_14','iso8859_15','iso8859_16','johab','koi8_r','koi8_t',
          'koi8_u','kz1048','mac_cyrillic','mac_greek','mac_iceland','mac_latin2','mac_roman','mac_turkish','ptcp154','shift_jis','shift_jis_2004',
          'shift_jisx0213','utf_32','utf_32_be','utf_32_le','utf_16','utf_16_be','utf_16_le','utf_7','utf_8','utf_8_sig']


for x in range(len(codecs)):
    # print(x,': Now checking use of:', codecs[x])
    try:
        df = pd.read_csv("./dataset/week14.csv",encoding = (codecs[x]))
        print('I can load data for', codecs[x], '\n')
    except:
        continue
# Out:
# I can load data for cp437
#
# I can load data for cp720
#
# I can load data for cp737
#
# I can load data for cp775
#
# I can load data for cp850
#
# I can load data for cp852
#
# I can load data for cp855
#
# I can load data for cp858
#
# I can load data for cp860
#
# I can load data for cp861
#
# I can load data for cp862
#
# I can load data for cp863
#
# I can load data for cp865
#
# I can load data for cp866
#
# I can load data for cp1006
#
# I can load data for cp1125
#
# I can load data for cp1256
#
# I can load data for latin_1
#
# I can load data for iso8859_2
#
# I can load data for iso8859_4
#
# I can load data for iso8859_5
#
# I can load data for iso8859_9
#
# I can load data for iso8859_10
#
# I can load data for iso8859_13
#
# I can load data for iso8859_14
#
# I can load data for iso8859_15
#
# I can load data for iso8859_16
#
# I can load data for koi8_r
#
# I can load data for koi8_u
#
# I can load data for mac_cyrillic
#
# I can load data for mac_greek
#
# I can load data for mac_iceland
#
# I can load data for mac_latin2
#
# I can load data for mac_roman
#
# I can load data for mac_turkish
#
# I can load data for ptcp154

# %%
cp437

# %%
df= pd.read_csv("./dataset/week1.csv",encoding='iso8859_16')
# Out:
# /tmp/ipykernel_27229/3496935204.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("./dataset/week1.csv",encoding='iso8859_16')

# %%
df.head()
# Out:
#           mid retweeted_status_mid        uid retweeted_uid        source  \
# 0  mCClUNCqwe           mU5j0dIAkQ  uK3RXUJ0V           NaN  æ°æ”ȘćŸźć
# 1  mRsOcOLTlc           mJGNX5nAmo  uK3RXUJ0V           NaN  æ°æ”ȘćŸźć
# 2  mH44qG6iUm           mH44qL9LlF  uK3RXUJ0V           NaN  æ°æ”ȘćŸźć
# 3  mZmwFtOdVX           mcyE5GR7GJ  uK3RXUJ0V           NaN  æ°æ”ȘćŸźć
# 4  mQkLJSl8bf           muy8VxftBB  uK3RXUJ0V           NaN  æ°æ”ȘćŸźć
#
#    image                                               text  geo  \
# 0      0                                       èœŹććŸźć  NaN
# 1      0  !!!!!!!!!@uK3RXUYW3ïŒ //@u0AGMTTVDïŒ  ïŒïŒ...  NaN
# 2      0                                 æ±äžćé ć©!!!  NaN
# 3      0  æłèŠ><@uK3RXUYW3ïŒ //@uknïŒ  ć
# šéœæłèŠć...  NaN
# 4      0           //@uknïŒ  //@uMLLV3ZCOïŒ  èœŹććŸźć  NaN
#
#             created_at deleted_last_seen permission_denied
# 0  2012-01-03 02:02:27               NaN               NaN
# 1  2012-01-03 01:17:39               NaN               NaN
# 2  2012-01-03 01:15:36               NaN               NaN
# 3  2012-01-03 01:12:55               NaN               NaN
# 4  2012-01-03 01:10:42               NaN               NaN
